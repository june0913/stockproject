# %% [markdown]
# ## 1. 회사 기본 정보 테이블 (Companies)

# %%
import pandas as pd
import yfinance as yf

# S&P 500 회사들의 티커 심볼이 포함된 CSV 파일을 불러옵니다.
sp500 = pd.read_csv('./sp500_companies.csv')
sp500_tickers = sp500['Symbol']

# 정보를 저장할 빈 리스트 생성
selected_info = []

# 각 티커 심볼에 대하여 필요한 정보만을 가져옵니다.
for ticker_symbol in sp500_tickers:
    stock = yf.Ticker(ticker_symbol)
    info = stock.info

    # 필요한 정보만을 추출하여 리스트에 추가합니다.
    selected_info.append({
        "symbol": info.get("symbol"),
        "companyName": info.get("longName"),
        "industry": info.get("industry"),
        "sector": info.get("sector"),

    })

# 리스트를 데이터프레임으로 변환
data = pd.DataFrame(selected_info)

# 데이터프레임을 CSV 파일로 저장
file_path = "C:\\Users\\mit14\\Desktop\\project\\Untitled Folder\\Enterprise.csv"  # 저장할 파일 경로
data.to_csv(file_path, index=False)
print(f"Data saved to {file_path}")

# %% [markdown]
# ## 2. 주가 정보 테이블 (StockPrices)

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

# S&P 500 회사들의 티커 심볼이 포함된 CSV 파일을 불러옵니다.
sp500 = pd.read_csv('./sp500_companies.csv')
sp500_tickers = sp500['Symbol']

# 데이터를 저장할 빈 리스트 생성
data = []

# 각 티커 심볼에 대하여 필요한 정보만을 가져옵니다.
for ticker_symbol in sp500_tickers:
    # yfinance를 사용하여 주식 정보 다운로드
    stock = yf.Ticker(ticker_symbol)
    info = stock.info
    
    # 가져온 정보에서 필요한 부분을 선택하고 리스트에 추가
    data.append({
        'Symbol': ticker_symbol,
        'Name': info.get('shortName', ''),
        'Sector': info.get('sector', ''),
        'Country': info.get('country', '')
    })

# 데이터프레임으로 변환
df = pd.DataFrame(data)

# CSV 파일로 저장
csv_file_path = "C:/Users/mit14/Desktop/project/Untitled Folder/sp500_company_info.csv"  # 저장할 파일 경로와 이름
df.to_csv(csv_file_path, index=False)

print(f"Data saved to {csv_file_path}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Data saved to C:/Users/mit14/Desktop/project/Untitled Folder/sp500_yesterday_hourly.csv

# %% [markdown]
# ## 3. 기사 정보 테이블 (NewsArticles)

# %%
import requests

def fetch_news(api_key, query, from_date, to_date, language='en'):
    url = 'https://newsapi.org/v2/everything'
    params = {
        'q': query,
        'from': from_date,
        'to': to_date,
        'language': language,
        'apiKey': api_key
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()['articles']
    else:
        print("Failed to fetch news")
        return None

# 사용 예시
api_key = 'bdfe72be91334fb5a5fb41fdbd4fc597'
query = 'JNJ'  # 뉴스를 검색할 종목명 또는 관련 키워드
from_date = '2024-02-01'  # 검색 시작 날짜
to_date = '2024-02-28'  # 검색 종료 날짜

news_articles = fetch_news(api_key, query, from_date, to_date)

for article in news_articles[:5]:  # 상위 5개 기사 출력
    print(f"Title: {article['title']}\nDescription: {article['description']}\nURL: {article['url']}\n")


# 데이터프레임을 CSV 파일로 저장
news_articles = "C:/Users/mit14/Desktop/project/Untitled Folder/news_articles.csv"  # 저장할 파일 경로와 이름
data.to_csv(news_articles)

print(f"Data saved to {news_articles}")

# %% [markdown]
# ## 4. 재무 정보 테이블 (Financials)

# %%
## 일단 불

# %% [markdown]
# ## 5. 분석 데이터 테이블 (AnalystRatings)

# %% [markdown]
# ## 6. 기업의 분기 및 연간 보고서를 저장합니다.

# %% [markdown]
# ## 7. 기업이 발행한 배당에 관한 정보를 저장합니다.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# S&P 500 회사들의 티커 심볼이 포함된 CSV 파일을 불러옵니다.
sp500 = pd.read_csv('./sp500_companies.csv')
sp500_tickers = sp500['Symbol']

# 정보를 저장할 빈 리스트 생성
selected_info = []

# 각 티커 심볼에 대하여 필요한 정보만을 가져옵니다.
for ticker_symbol in sp500_tickers:
    stock = yf.Ticker(ticker_symbol)
    info = stock.info

# 요청 헤더 설정
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# GET 요청을 보내고 응답을 받아옴
response = requests.get(url, headers=headers)

# 응답의 상태코드를 확인하여 성공적으로 받아왔는지 확인
if response.status_code == 200:
    # BeautifulSoup을 사용하여 HTML을 파싱
    soup = BeautifulSoup(response.text, 'html.parser')

    # 배당 정보가 들어있는 테이블을 찾음
    dividend_table = soup.find_all('table', class_='W(100%) M(0)')[0]

    # 첫 번째 행은 헤더이므로 스킵
    rows = dividend_table.find_all('tr')[1:]

    # 데이터를 저장할 빈 리스트 생성
    data = []

    # 각 행을 순회하며 데이터 추출
    for row in rows:
        # 각 열을 추출
        columns = row.find_all('td')
        if len(columns) >= 5:  # 최소한의 열이 존재하는지 확인
            declaration_date = columns[0].text.strip()
            ex_dividend_date = columns[1].text.strip()
            payment_date = columns[2].text.strip()
            dividend_amount = columns[3].text.strip()

            # 추출한 데이터를 딕셔너리로 묶어 리스트에 추가
            data.append({
                'Declaration Date': declaration_date,
                'Ex-Dividend Date': ex_dividend_date,
                'Payment Date': payment_date,
                'Dividend Amount': dividend_amount
            })

    # 리스트를 데이터프레임으로 변환
    df = pd.DataFrame(data)

    # 데이터프레임을 CSV 파일로 저장
    file_path = "C:/Users/mit14/Desktop/project/Untitled Folder/dividend_info.csv"  # 저장할 파일 경로와 이름
    df.to_csv(file_path, index=False)

    print(f"Data saved to {file_path}")
else:
    print("Failed to retrieve data from the website. Status code:", response.status_code)
# Out:
# Declaration Date: Feb 28, 2024
# Ex-Dividend Date: 182.51
# Payment Date: 183.12
# Dividend Amount: 180.13
#
# Declaration Date: Feb 27, 2024
# Ex-Dividend Date: 181.10
# Payment Date: 183.92
# Dividend Amount: 179.56
#
# Declaration Date: Feb 26, 2024
# Ex-Dividend Date: 182.24
# Payment Date: 182.76
# Dividend Amount: 180.65
#
# Declaration Date: Feb 23, 2024
# Ex-Dividend Date: 185.01
# Payment Date: 185.04
# Dividend Amount: 182.23
#
# Declaration Date: Feb 22, 2024
# Ex-Dividend Date: 183.48
# Payment Date: 184.96
# Dividend Amount: 182.46
#
# Declaration Date: Feb 21, 2024
# Ex-Dividend Date: 181.94
# Payment Date: 182.89
# Dividend Amount: 180.66
#
# Declaration Date: Feb 20, 2024
# Ex-Dividend Date: 181.79
# Payment Date: 182.43
# Dividend Amount: 180.00
#
# Declaration Date: Feb 16, 2024
# Ex-Dividend Date: 183.42
# Payment Date: 184.85
# Dividend Amount: 181.67
#
# Declaration Date: Feb 15, 2024
# Ex-Dividend Date: 183.55
# Payment Date: 184.49
# Dividend Amount: 181.35
#
# Declaration Date: Feb 14, 2024
# Ex-Dividend Date: 185.32
# Payment Date: 185.53
# Dividend Amount: 182.44
#
# Declaration Date: Feb 13, 2024
# Ex-Dividend Date: 185.77
# Payment Date: 186.21
# Dividend Amount: 183.51
#
# Declaration Date: Feb 12, 2024
# Ex-Dividend Date: 188.42
# Payment Date: 188.67
# Dividend Amount: 186.79
#
# Declaration Date: Feb 09, 2024
# Ex-Dividend Date: 188.65
# Payment Date: 189.99
# Dividend Amount: 188.00
#
# Declaration Date: Feb 08, 2024
# Ex-Dividend Date: 189.39
# Payment Date: 189.54
# Dividend Amount: 187.35
#
# Declaration Date: Feb 07, 2024
# Ex-Dividend Date: 190.64
# Payment Date: 191.05
# Dividend Amount: 188.61
#
# Declaration Date: Feb 06, 2024
# Ex-Dividend Date: 186.86
# Payment Date: 189.31
# Dividend Amount: 186.77
#
# Declaration Date: Feb 05, 2024
# Ex-Dividend Date: 188.15
# Payment Date: 189.25
# Dividend Amount: 185.84
#
# Declaration Date: Feb 02, 2024
# Ex-Dividend Date: 179.86
# Payment Date: 187.33
# Dividend Amount: 179.25
#
# Declaration Date: Feb 01, 2024
# Ex-Dividend Date: 183.99
# Payment Date: 186.95
# Dividend Amount: 183.82
#
# Declaration Date: Jan 31, 2024
# Ex-Dividend Date: 187.04
# Payment Date: 187.10
# Dividend Amount: 184.35
#
# Declaration Date: Jan 30, 2024
# Ex-Dividend Date: 190.94
# Payment Date: 191.80
# Dividend Amount: 187.47
#
# Declaration Date: Jan 29, 2024
# Ex-Dividend Date: 192.01
# Payment Date: 192.20
# Dividend Amount: 189.58
#
# Declaration Date: Jan 26, 2024
# Ex-Dividend Date: 194.27
# Payment Date: 194.76
# Dividend Amount: 191.94
#
# Declaration Date: Jan 25, 2024
# Ex-Dividend Date: 195.22
# Payment Date: 196.27
# Dividend Amount: 193.11
#
# Declaration Date: Jan 24, 2024
# Ex-Dividend Date: 195.42
# Payment Date: 196.38
# Dividend Amount: 194.34
#
# Declaration Date: Jan 23, 2024
# Ex-Dividend Date: 195.02
# Payment Date: 195.75
# Dividend Amount: 193.83
#
# Declaration Date: Jan 22, 2024
# Ex-Dividend Date: 192.30
# Payment Date: 195.33
# Dividend Amount: 192.26
#
# Declaration Date: Jan 19, 2024
# Ex-Dividend Date: 189.33
# Payment Date: 191.95
# Dividend Amount: 188.82
#
# Declaration Date: Jan 18, 2024
# Ex-Dividend Date: 186.09
# Payment Date: 189.14
# Dividend Amount: 185.83
#
# Declaration Date: Jan 17, 2024
# Ex-Dividend Date: 181.27
# Payment Date: 182.93
# Dividend Amount: 180.30
#
# Declaration Date: Jan 16, 2024
# Ex-Dividend Date: 182.16
# Payment Date: 184.26
# Dividend Amount: 180.93
#
# Declaration Date: Jan 12, 2024
# Ex-Dividend Date: 186.06
# Payment Date: 186.74
# Dividend Amount: 185.19
#
# Declaration Date: Jan 11, 2024
# Ex-Dividend Date: 186.54
# Payment Date: 187.05
# Dividend Amount: 183.62
#
# Declaration Date: Jan 10, 2024
# Ex-Dividend Date: 184.35
# Payment Date: 186.40
# Dividend Amount: 183.92
#
# Declaration Date: Jan 09, 2024
# Ex-Dividend Date: 183.92
# Payment Date: 185.15
# Dividend Amount: 182.73
#
# Declaration Date: Jan 08, 2024
# Ex-Dividend Date: 182.09
# Payment Date: 185.60
# Dividend Amount: 181.50
#
# Declaration Date: Jan 05, 2024
# Ex-Dividend Date: 181.99
# Payment Date: 182.76
# Dividend Amount: 180.17
#
# Declaration Date: Jan 04, 2024
# Ex-Dividend Date: 182.15
# Payment Date: 183.09
# Dividend Amount: 180.88
#
# Declaration Date: Jan 03, 2024
# Ex-Dividend Date: 184.22
# Payment Date: 185.88
# Dividend Amount: 183.43
#
# Declaration Date: Jan 02, 2024
# Ex-Dividend Date: 187.15
# Payment Date: 188.44
# Dividend Amount: 183.89
#
# Declaration Date: Dec 29, 2023
# Ex-Dividend Date: 193.90
# Payment Date: 194.40
# Dividend Amount: 191.73
#
# Declaration Date: Dec 28, 2023
# Ex-Dividend Date: 194.14
# Payment Date: 194.66
# Dividend Amount: 193.17
#
# Declaration Date: Dec 27, 2023
# Ex-Dividend Date: 192.49
# Payment Date: 193.50
# Dividend Amount: 191.09
#
# Declaration Date: Dec 26, 2023
# Ex-Dividend Date: 193.61
# Payment Date: 193.89
# Dividend Amount: 192.83
#
# Declaration Date: Dec 22, 2023
# Ex-Dividend Date: 195.18
# Payment Date: 195.41
# Dividend Amount: 192.97
#
# Declaration Date: Dec 21, 2023
# Ex-Dividend Date: 196.10
# Payment Date: 197.08
# Dividend Amount: 193.50
#
# Declaration Date: Dec 20, 2023
# Ex-Dividend Date: 196.90
# Payment Date: 197.68
# Dividend Amount: 194.83
#
# Declaration Date: Dec 19, 2023
# Ex-Dividend Date: 196.16
# Payment Date: 196.95
# Dividend Amount: 195.89
#
# Declaration Date: Dec 18, 2023
# Ex-Dividend Date: 196.09
# Payment Date: 196.63
# Dividend Amount: 194.39
#
# Declaration Date: Dec 15, 2023
# Ex-Dividend Date: 197.53
# Payment Date: 198.40
# Dividend Amount: 197.00
#
# Declaration Date: Dec 14, 2023
# Ex-Dividend Date: 198.02
# Payment Date: 199.62
# Dividend Amount: 196.16
#
# Declaration Date: Dec 13, 2023
# Ex-Dividend Date: 195.09
# Payment Date: 198.00
# Dividend Amount: 194.85
#
# Declaration Date: Dec 12, 2023
# Ex-Dividend Date: 193.08
# Payment Date: 194.72
# Dividend Amount: 191.72
#
# Declaration Date: Dec 11, 2023
# Ex-Dividend Date: 193.11
# Payment Date: 193.49
# Dividend Amount: 191.42
#
# Declaration Date: Dec 08, 2023
# Ex-Dividend Date: 194.20
# Payment Date: 195.99
# Dividend Amount: 193.67
#
# Declaration Date: Dec 07, 2023
# Ex-Dividend Date: 193.63
# Payment Date: 195.00
# Dividend Amount: 193.59
#
# Declaration Date: Dec 06, 2023
# Ex-Dividend Date: 194.45
# Payment Date: 194.76
# Dividend Amount: 192.11
#
# Declaration Date: Dec 05, 2023
# Ex-Dividend Date: 190.21
# Payment Date: 194.40
# Dividend Amount: 190.18
#
# Declaration Date: Dec 04, 2023
# Ex-Dividend Date: 189.98
# Payment Date: 190.05
# Dividend Amount: 187.45
#
# Declaration Date: Dec 01, 2023
# Ex-Dividend Date: 190.33
# Payment Date: 191.56
# Dividend Amount: 189.23
#
# Declaration Date: Nov 30, 2023
# Ex-Dividend Date: 189.84
# Payment Date: 190.32
# Dividend Amount: 188.19
#
# Declaration Date: Nov 29, 2023
# Ex-Dividend Date: 190.90
# Payment Date: 192.09
# Dividend Amount: 188.97
#
# Declaration Date: Nov 28, 2023
# Ex-Dividend Date: 189.78
# Payment Date: 191.08
# Dividend Amount: 189.40
#
# Declaration Date: Nov 27, 2023
# Ex-Dividend Date: 189.92
# Payment Date: 190.67
# Dividend Amount: 188.90
#
# Declaration Date: Nov 24, 2023
# Ex-Dividend Date: 190.87
# Payment Date: 190.90
# Dividend Amount: 189.25
#
# Declaration Date: Nov 22, 2023
# Ex-Dividend Date: 191.49
# Payment Date: 192.93
# Dividend Amount: 190.83
#
# Declaration Date: Nov 21, 2023
# Ex-Dividend Date: 191.41
# Payment Date: 191.52
# Dividend Amount: 189.74
#
# Declaration Date: Nov 20, 2023
# Ex-Dividend Date: 189.89
# Payment Date: 191.91
# Dividend Amount: 189.88
#
# Declaration Date: Nov 17, 2023
# Ex-Dividend Date: 190.25
# Payment Date: 190.38
# Dividend Amount: 188.57
#
# Declaration Date: Nov 16, 2023
# Ex-Dividend Date: 189.57
# Payment Date: 190.96
# Dividend Amount: 188.65
#
# Declaration Date: Nov 15, 2023
# Ex-Dividend Date: 187.85
# Payment Date: 189.50
# Dividend Amount: 187.78
#
# Declaration Date: Nov 14, 2023
# Ex-Dividend Date: 187.70
# Payment Date: 188.11
# Dividend Amount: 186.30
#
# Declaration Date: Nov 13, 2023
# Ex-Dividend Date: 185.82
# Payment Date: 186.03
# Dividend Amount: 184.21
#
# Declaration Date: Nov 10, 2023
# Ex-Dividend Date: 183.97
# Payment Date: 186.57
# Dividend Amount: 183.53
#
# Declaration Date: Nov 09, 2023
# Ex-Dividend Date: 182.96
# Payment Date: 184.12
# Dividend Amount: 181.81
#
# Declaration Date: Nov 08, 2023
# Ex-Dividend Date: 182.35
# Payment Date: 183.45
# Dividend Amount: 181.59
#
# Declaration Date: Nov 07, 2023
# Ex-Dividend Date: 179.18
# Payment Date: 182.44
# Dividend Amount: 178.97
#
# Declaration Date: Nov 06, 2023
# Ex-Dividend Date: 176.38
# Payment Date: 179.43
# Dividend Amount: 176.21
#
# Declaration Date: Nov 03, 2023
# Ex-Dividend Date: 174.24
# Payment Date: 176.82
# Dividend Amount: 173.35
#
# Declaration Date: Nov 02, 2023
# Ex-Dividend Date: 175.52
# Payment Date: 177.78
# Dividend Amount: 175.46
#
# Declaration Date: Nov 01, 2023
# Ex-Dividend Date: 171.00
# Payment Date: 174.23
# Dividend Amount: 170.12
#
# Declaration Date: Oct 31, 2023
# Ex-Dividend Date: 169.35
# Payment Date: 170.90
# Dividend Amount: 167.90
#
# Declaration Date: Oct 30, 2023
# Ex-Dividend Date: 169.02
# Payment Date: 171.17
# Dividend Amount: 168.87
#
# Declaration Date: Oct 27, 2023
# Ex-Dividend Date: 166.91
# Payment Date: 168.96
# Dividend Amount: 166.83
#
# Declaration Date: Oct 26, 2023
# Ex-Dividend Date: 170.37
# Payment Date: 171.38
# Dividend Amount: 165.67
#
# Declaration Date: Oct 25, 2023
# Ex-Dividend Date: 171.88
# Payment Date: 173.06
# Dividend Amount: 170.65
#
# Declaration Date: Oct 24, 2023
# Ex-Dividend Date: 173.05
# Payment Date: 173.67
# Dividend Amount: 171.45
#
# Declaration Date: Oct 23, 2023
# Ex-Dividend Date: 170.91
# Payment Date: 174.01
# Dividend Amount: 169.93
#
# Declaration Date: Oct 20, 2023
# Ex-Dividend Date: 175.31
# Payment Date: 175.42
# Dividend Amount: 172.64
#
# Declaration Date: Oct 19, 2023
# Ex-Dividend Date: 176.04
# Payment Date: 177.84
# Dividend Amount: 175.19
#
# Declaration Date: Oct 18, 2023
# Ex-Dividend Date: 175.58
# Payment Date: 177.58
# Dividend Amount: 175.11
#
# Declaration Date: Oct 17, 2023
# Ex-Dividend Date: 176.65
# Payment Date: 178.42
# Dividend Amount: 174.80
#
# Declaration Date: Oct 16, 2023
# Ex-Dividend Date: 176.75
# Payment Date: 179.08
# Dividend Amount: 176.51
#
# Declaration Date: Oct 13, 2023
# Ex-Dividend Date: 181.42
# Payment Date: 181.93
# Dividend Amount: 178.14
#
# Declaration Date: Oct 12, 2023
# Ex-Dividend Date: 180.07
# Payment Date: 182.34
# Dividend Amount: 179.04
#
# Declaration Date: Oct 11, 2023
# Ex-Dividend Date: 178.20
# Payment Date: 179.85
# Dividend Amount: 177.60
#
# Declaration Date: Oct 10, 2023
# Ex-Dividend Date: 178.10
# Payment Date: 179.72
# Dividend Amount: 177.95
#
# Declaration Date: Oct 09, 2023
# Ex-Dividend Date: 176.81
# Payment Date: 179.05
# Dividend Amount: 175.80
#
# Data saved to C:/Users/mit14/Desktop/project/Untitled Folder/response.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import yfinance as yf  # yfinance 모듈 임포트

# S&P 500 회사들의 티커 심볼이 포함된 CSV 파일을 불러옵니다.
sp500 = pd.read_csv('./sp500_companies.csv')
sp500_tickers = sp500['Symbol']

# 정보를 저장할 빈 리스트 생성
data = []

# 각 티커 심볼에 대하여 필요한 정보만을 가져옵니다.
for ticker_symbol in sp500_tickers:
    stock = yf.Ticker(ticker_symbol)
    info = stock.info

    # 요청 헤더 설정
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    # GET 요청을 보내고 응답을 받아옴
    url = f'https://finance.yahoo.com/quote/{ticker_symbol}/history'
    response = requests.get(url, headers=headers)

    # 응답의 상태코드를 확인하여 성공적으로 받아왔는지 확인
    if response.status_code == 200:
        # BeautifulSoup을 사용하여 HTML을 파싱
        soup = BeautifulSoup(response.text, 'html.parser')

        # 배당 정보가 들어있는 테이블을 찾음
        dividend_tables = soup.find_all('table', class_='W(100%) M(0)')

        # 테이블이 존재하는 경우에만 데이터 추출
        if dividend_tables:
            dividend_table = dividend_tables[0]

            # 첫 번째 행은 헤더이므로 스킵
            rows = dividend_table.find_all('tr')[1:]

            # 각 행을 순회하며 데이터 추출
            for row in rows:
                # 각 열을 추출
                columns = row.find_all('td')
                if len(columns) >= 5:  # 최소한의 열이 존재하는지 확인
                    declaration_date = columns[0].text.strip()
                    ex_dividend_date = columns[1].text.strip()
                    payment_date = columns[2].text.strip()
                    dividend_amount = columns[3].text.strip()

                    # 추출한 데이터를 딕셔너리로 묶어 리스트에 추가
                    data.append({
                        'Ticker Symbol': ticker_symbol,
                        'Declaration Date': declaration_date,
                        'Ex-Dividend Date': ex_dividend_date,
                        'Payment Date': payment_date,
                        'Dividend Amount': dividend_amount
                    })
    else:
        print(f"Failed to retrieve data for {ticker_symbol}. Status code:", response.status_code)

# 리스트를 데이터프레임으로 변환
df = pd.DataFrame(data)

# 데이터프레임을 CSV 파일로 저장
file_path = "C:/Users/mit14/Desktop/project/Untitled Folder/dividend_info.csv"  # 저장할 파일 경로와 이름
df.to_csv(file_path, index=False)

print(f"Data saved to {file_path}")
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ATVI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ATVI&crumb=2jU8oy0VXUb
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABC&crumb=2jU8oy0VXUb
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RE&crumb=2jU8oy0VXUb
# Data saved to C:/Users/mit14/Desktop/project/Untitled Folder/dividend_info.csv

# %% [markdown]
# ## 기본 데이터 불러오기

# %%
import requests
import pandas as pd
import io  # io 모듈에서 StringIO를 가져오기 위해 추가

# S&P 500 기업 목록이 담긴 CSV 파일의 URL입니다.
url = 'https://datahub.io/core/s-and-p-500-companies/r/0.csv'

# HTTP GET 요청을 보내어 파일을 다운로드합니다.
response = requests.get(url)

# 요청이 성공적이었는지 상태 코드로 확인합니다.
if response.status_code == 200:
    # 받아온 내용을 io.StringIO를 이용하여 CSV 형식으로 읽어 DataFrame 객체로 변환합니다.
    data = pd.read_csv(io.StringIO(response.text))
    
    # 데이터를 확인하기 위해 DataFrame의 처음 5행을 출력합니다.
    print(data.head())
else:
    # 요청이 실패했다면 오류 메시지를 출력합니다.
    print("데이터를 가져오지 못했습니다.")

# 데이터프레임을 CSV 파일로 저장
file_path = "C:/Users/mit14/Desktop/sp500_yesterday_hourly.csv"  # 저장할 파일 경로와 이름
data.to_csv(file_path)
print(f"Data saved to {file_path}")
# Out:
#   Symbol                 Name       Sector
# 0    MMM                   3M  Industrials
# 1    AOS          A. O. Smith  Industrials
# 2    ABT  Abbott Laboratories  Health Care
# 3   ABBV               AbbVie  Health Care
# 4   ABMD              Abiomed  Health Care
# Data saved to C:/Users/mit14/Desktop/sp500_yesterday_hourly.csv

# %% [markdown]
# ## 모든정보 불러오기

# %%
import yfinance as yf
sp500 = pd.read_csv('./sp500_companies.csv')
sp500_tg = sp500['Symbol']
# 특정 주식을 위한 티커 심볼, 예를 들어 Apple Inc.
for i in sp500_tg
ticker_symbol = "AAPL"

# yfinance를 사용하여 주식 정보 가져오기
stock = yf.Ticker(ticker_symbol)

# 가능한 모든 정보를 가져오기
info = stock.info

# 정보 출력
for key, value in info.items():
    print(f"{key}: {value}")
# Out:
# address1: One Apple Park Way
# city: Cupertino
# state: CA
# zip: 95014
# country: United States
# phone: 408 996 1010
# website: https://www.apple.com
# industry: Consumer Electronics
# industryKey: consumer-electronics
# industryDisp: Consumer Electronics
# sector: Technology
# sectorKey: technology
# sectorDisp: Technology
# longBusinessSummary: Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.
# fullTimeEmployees: 161000
# companyOfficers: [{'maxAge': 1, 'name': 'Mr. Timothy D. Cook', 'age': 62, 'title': 'CEO & Director', 'yearBorn': 1961, 'fiscalYear': 2023, 'totalPay': 16239562, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Luca  Maestri', 'age': 60, 'title': 'CFO & Senior VP', 'yearBorn': 1963, 'fiscalYear': 2023, 'totalPay': 4612242, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Jeffrey E. Williams', 'age': 59, 'title': 'Chief Operating Officer', 'yearBorn': 1964, 'fiscalYear': 2023, 'totalPay': 4637585, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Katherine L. Adams', 'age': 59, 'title': 'Senior VP, General Counsel & Secretary', 'yearBorn': 1964, 'fiscalYear': 2023, 'totalPay': 4618064, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': "Ms. Deirdre  O'Brien", 'age': 56, 'title': 'Senior Vice President of Retail', 'yearBorn': 1967, 'fiscalYear': 2023, 'totalPay': 4613369, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Chris  Kondo', 'title': 'Senior Director of Corporate Accounting', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. James  Wilson', 'title': 'Chief Technology Officer', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Suhasini  Chandramouli', 'title': 'Director of Investor Relations', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Greg  Joswiak', 'title': 'Senior Vice President of Worldwide Marketing', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Adrian  Perica', 'age': 49, 'title': 'Head of Corporate Development', 'yearBorn': 1974, 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}]
# auditRisk: 4
# boardRisk: 1
# compensationRisk: 5
# shareHolderRightsRisk: 1
# overallRisk: 1
# governanceEpochDate: 1709078400
# compensationAsOfEpochDate: 1703980800
# maxAge: 86400
# priceHint: 2
# previousClose: 182.63
# open: 182.51
# dayLow: 180.13
# dayHigh: 183.12
# regularMarketPreviousClose: 182.63
# regularMarketOpen: 182.51
# regularMarketDayLow: 180.13
# regularMarketDayHigh: 183.12
# dividendRate: 0.96
# dividendYield: 0.0053
# exDividendDate: 1707436800
# payoutRatio: 0.14770001
# fiveYearAvgDividendYield: 0.78
# beta: 1.312
# trailingPE: 28.258566
# forwardPE: 25.302649
# volume: 48687631
# regularMarketVolume: 48687631
# averageVolume: 54578896
# averageVolume10days: 51404420
# averageDailyVolume10Day: 51404420
# bidSize: 1000
# askSize: 900
# marketCap: 2801469489152
# fiftyTwoWeekLow: 143.9
# fiftyTwoWeekHigh: 199.62
# priceToSalesTrailing12Months: 7.263225
# fiftyDayAverage: 188.3896
# twoHundredDayAverage: 183.82495
# trailingAnnualDividendRate: 0.95
# trailingAnnualDividendYield: 0.0052017737
# currency: USD
# enterpriseValue: 2836405944320
# profitMargins: 0.26163
# floatShares: 15414703289
# sharesOutstanding: 15441899520
# sharesShort: 97665956
# sharesShortPriorMonth: 101263039
# sharesShortPreviousMonthDate: 1705017600
# dateShortInterest: 1707955200
# sharesPercentSharesOut: 0.0063
# heldPercentInsiders: 0.059369996
# heldPercentInstitutions: 0.56678003
# shortRatio: 1.71
# shortPercentOfFloat: 0.0063
# impliedSharesOutstanding: 15441899520
# bookValue: 4.793
# priceToBook: 37.851032
# lastFiscalYearEnd: 1696032000
# nextFiscalYearEnd: 1727654400
# mostRecentQuarter: 1703894400
# earningsQuarterlyGrowth: 0.131
# netIncomeToCommon: 100912996352
# trailingEps: 6.42
# forwardEps: 7.17
# pegRatio: 2.51
# lastSplitFactor: 4:1
# lastSplitDate: 1598832000
# enterpriseToRevenue: 7.354
# enterpriseToEbitda: 21.8
# 52WeekChange: 0.25166202
# SandP52WeekChange: 0.27549195
# lastDividendValue: 0.24
# lastDividendDate: 1707436800
# exchange: NMS
# quoteType: EQUITY
# symbol: AAPL
# underlyingSymbol: AAPL
# shortName: Apple Inc.
# longName: Apple Inc.
# firstTradeDateEpochUtc: 345479400
# timeZoneFullName: America/New_York
# timeZoneShortName: EST
# uuid: 8b10e4ae-9eeb-3684-921a-9ab27e4d87aa
# messageBoardId: finmb_24937
# gmtOffSetMilliseconds: -18000000
# currentPrice: 181.42
# targetHighPrice: 250.0
# targetLowPrice: 158.0
# targetMeanPrice: 201.41
# targetMedianPrice: 200.0
# recommendationMean: 2.2
# recommendationKey: buy
# numberOfAnalystOpinions: 39
# totalCash: 73100001280
# totalCashPerShare: 4.734
# ebitda: 130108997632
# totalDebt: 108040003584
# quickRatio: 0.92
# currentRatio: 1.073
# totalRevenue: 385706000384
# debtToEquity: 145.803
# revenuePerShare: 24.648
# returnOnAssets: 0.21181
# returnOnEquity: 1.5426899
# freeCashflow: 86563127296
# operatingCashflow: 116433002496
# earningsGrowth: 0.16
# revenueGrowth: 0.021
# grossMargins: 0.45027
# ebitdaMargins: 0.33733
# operatingMargins: 0.33764
# financialCurrency: USD
# trailingPegRatio: 2.2332

# %% [markdown]
# ## 필요 데이터 불러오기

# %%
import pandas as pd
import yfinance as yf

# S&P 500 회사들의 티커 심볼이 포함된 CSV 파일을 불러옵니다.
sp500 = pd.read_csv('./sp500_companies.csv')
sp500_tickers = sp500['Symbol']

# 정보를 저장할 빈 리스트 생성
selected_info = []

# 각 티커 심볼에 대하여 필요한 정보만을 가져옵니다.
for ticker_symbol in sp500_tickers:
    stock = yf.Ticker(ticker_symbol)
    info = stock.info

    # 필요한 정보만을 추출하여 리스트에 추가합니다.
    selected_info.append({
        "symbol": info.get("symbol"),
        "companyName": info.get("longName"),
        "industry": info.get("industry"),
        "sector": info.get("sector"),
        "netIncomeToCommon": info.get("netIncomeToCommon"),
        "totalRevenue": info.get("totalRevenue"),
        "ebitda": info.get("ebitda"),
        "totalDebt": info.get("totalDebt"),
        "currentRatio": info.get("currentRatio"),
        "returnOnAssets": info.get("returnOnAssets"),
        "returnOnEquity": info.get("returnOnEquity"),
        "grossMargins": info.get("grossMargins"),
        "operatingMargins": info.get("operatingMargins")
    })

# 리스트를 데이터프레임으로 변환
data = pd.DataFrame(selected_info)

# 데이터프레임을 CSV 파일로 저장
file_path = "C:\\Users\\mit14\\Desktop\\project\\Untitled Folder\\Enterprise.csv"  # 저장할 파일 경로
data.to_csv(file_path, index=False)
print(f"Data saved to {file_path}")
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ATVI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ATVI&crumb=2jU8oy0VXUb
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABC&crumb=2jU8oy0VXUb
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RE&crumb=2jU8oy0VXUb
# Data saved to C:\Users\mit14\Desktop\project\Untitled Folder\Enterprise.csv

# %% [markdown]
# ## 국내 기사 불러오기(날짜 조율 안됨)

# %%
import feedparser

# Google News RSS 피드 URL을 설정합니다. 테슬라에 관한 뉴스를 예로 듭니다.
rss_url = 'https://news.google.com/rss/search?q=테슬라&hl=ko&gl=KR&ceid=KR:ko'

# feedparser를 사용하여 RSS 피드를 파싱합니다.
feed = feedparser.parse(rss_url)

# 파싱된 뉴스 항목을 순회하며 제목을 출력합니다.
for entry in feed.entries:
    print(f"Title: {entry.title}")
    print(f"Link: {entry.link}\n")
# Out:
# Title: “타도 테슬라” 외치던 벤츠·포드, 왜 ‘전기차 올인’ 버리고 방향 틀었나 - 조선일보
# Link: https://news.google.com/rss/articles/CBMiSmh0dHBzOi8vd3d3LmNob3N1bi5jb20vZWNvbm9teS9hdXRvLzIwMjQvMDIvMjcvMlBPU1JMR0VRUkJFVEJGTElWVjZKS05CNkEv0gFZaHR0cHM6Ly93d3cuY2hvc3VuLmNvbS9lY29ub215L2F1dG8vMjAyNC8wMi8yNy8yUE9TUkxHRVFSQkVUQkZMSVZWNkpLTkI2QS8_b3V0cHV0VHlwZT1hbXA?oc=5
#
# Title: "역대 가장 놀라운 제품"…테슬라, 로드스터 내년 출시 - 한국경제
# Link: https://news.google.com/rss/articles/CBMiLmh0dHBzOi8vd3d3Lmhhbmt5dW5nLmNvbS9hcnRpY2xlLzIwMjQwMjI4NzMxMGnSASpodHRwczovL3d3dy5oYW5reXVuZy5jb20vYW1wLzIwMjQwMjI4NzMxMGk?oc=5
#
# Title: 애플 전기차 포기에 테슬라 등 차 업계가 '안도'하는 이유 - 연합뉴스
# Link: https://news.google.com/rss/articles/CBMiL2h0dHBzOi8vd3d3LnluYS5jby5rci92aWV3L0FLUjIwMjQwMjI4MDQxNjAwMDA50gEA?oc=5
#
# Title: 테슬라 모델3 롱레인지 가격 또 인상…그래서 얼만데? - 디지털투데이
# Link: https://news.google.com/rss/articles/CBMiQWh0dHBzOi8vd3d3LmRpZ2l0YWx0b2RheS5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NTA3MTky0gEA?oc=5
#
# Title: [50초 리포트] 테슬라 '노쇼'에 대박 난 파이 가게 - KBS뉴스
# Link: https://news.google.com/rss/articles/CBMiL2h0dHBzOi8vbmV3cy5rYnMuY28ua3IvbmV3cy92aWV3LmRvP25jZD03OTAwOTc50gEA?oc=5
#
# Title: 테슬라, '피규어 견제용' 휴머노이드 영상 공개 < 포토/영상 < 포커스 < 기사본문 - AI타임스
# Link: https://news.google.com/rss/articles/CBMiOmh0dHBzOi8vd3d3LmFpdGltZXMuY29tL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0xNTc0OTDSAQA?oc=5
#
# Title: 테슬라 꺾은 中BYD, 이번엔 3억원대 슈퍼카 출시 - 아시아경제
# Link: https://news.google.com/rss/articles/CBMiM2h0dHBzOi8vd3d3LmFzaWFlLmNvLmtyL2FydGljbGUvMjAyNDAyMjYxNTA5MDcyNjY4NdIBAA?oc=5
#
# Title: “테슬라에서 소송 안 하면 다행"... 바퀴 6개 달린 대륙의 사이버트럭, 그 정체는? - 오토트리뷴
# Link: https://news.google.com/rss/articles/CBMiP2h0dHBzOi8vd3d3LmF1dG90cmlidW5lLmNvLmtyL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0xNDA4OdIBAA?oc=5
#
# Title: KB證 “서학개미 매매 1위 종목, 테슬라” - 데일리안
# Link: https://news.google.com/rss/articles/CBMiKWh0dHBzOi8vbS5kYWlsaWFuLmNvLmtyL25ld3Mvdmlldy8xMzMzNDA30gEA?oc=5
#
# Title: KB증권 "테슬라, 고객들이 가장 사랑한 미국 주식" - 이투데이
# Link: https://news.google.com/rss/articles/CBMiKmh0dHBzOi8vd3d3LmV0b2RheS5jby5rci9uZXdzL3ZpZXcvMjMzNTU5NdIBAA?oc=5
#
# Title: KB증권 "서학개미 최대 매수 美주식은 테슬라" - 서울와이어
# Link: https://news.google.com/rss/articles/CBMiPGh0dHBzOi8vd3d3LnNlb3Vsd2lyZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTUzMjkxM9IBAA?oc=5
#
# Title: 일론 머스크, 테슬라 팬들에게 1초 미만의 0-60 가속을 약속한 로드스터 출시 예고—'이런 차는 다시 없을 것' - 포춘코리아
# Link: https://news.google.com/rss/articles/CBMiQGh0dHBzOi8vd3d3LmZvcnR1bmVrb3JlYS5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MzUwOTHSAUNodHRwczovL3d3dy5mb3J0dW5la29yZWEuY28ua3IvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTM1MDkx?oc=5
#
# Title: 테슬라, 반값 전기차 대신 전기 스포츠카 ‘로드스터’ 2세대 공개... BYD 스포츠카 겨냥한 로드스터 내년부터 고객 인도 시작한다! - AVING.net
# Link: https://news.google.com/rss/articles/CBMiOGh0dHBzOi8va3IuYXZpbmcubmV0L25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0xNzg4NTQ20gE7aHR0cHM6Ly9rci5hdmluZy5uZXQvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTE3ODg1NDY?oc=5
#
# Title: 머스크 “신형 테슬라 로드스터 스포츠카 내년 출시···제로백 1초 미만” - 이코노믹리뷰
# Link: https://news.google.com/rss/articles/CBMiPGh0dHBzOi8vd3d3LmVjb25vdmlsbC5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTY0NzM5N9IBAA?oc=5
#
# Title: 이걸 믿어야 하나? 테슬라, "2세대 로드스터 가속 성능은 1초 이내" - 모터그래프
# Link: https://news.google.com/rss/articles/CBMiPGh0dHBzOi8vd3d3Lm1vdG9yZ3JhcGguY29tL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0zMzM3MdIBAA?oc=5
#
# Title: "애플 전기차 포기 환영" … 테슬라 주가 화답 [월가 이종목] - 뉴데일리
# Link: https://news.google.com/rss/articles/CBMiR2h0dHBzOi8vd3d3Lm5ld2RhaWx5LmNvLmtyL3NpdGUvZGF0YS9odG1sLzIwMjQvMDIvMjkvMjAyNDAyMjkwMDAyNC5odG1s0gEA?oc=5
#
# Title: BYD “미국 시장 진출 계획 없다” 테슬라 안도의 한숨 - 뉴스1
# Link: https://news.google.com/rss/articles/CBMiJmh0dHBzOi8vd3d3Lm5ld3MxLmtyL2FydGljbGVzLz81MzM2MzE30gEqaHR0cHM6Ly93d3cubmV3czEua3IvYW1wL2FydGljbGVzLz81MzM2MzE3?oc=5
#
# Title: 애플, 자율주행 전기차 개발 포기...애플·테슬라·현대차 주가 동반급등 이유 [투자박사] 시티타임스 CityTimes - Investing.com
# Link: https://news.google.com/rss/articles/CBMiNWh0dHBzOi8va3IuaW52ZXN0aW5nLmNvbS9uZXdzL2Vjb25vbXkvYXJ0aWNsZS0xMDEzODAw0gEA?oc=5
#
# Title: 애플, 10년 쏟은 ‘애플카’ 개발 철수… 테슬라 ‘방긋’ - 세계일보
# Link: https://news.google.com/rss/articles/CBMiLWh0dHBzOi8vd3d3LnNlZ3llLmNvbS9uZXdzVmlldy8yMDI0MDIyODUxNjk1MtIBKmh0dHBzOi8vbS5zZWd5ZS5jb20vYW1wVmlldy8yMDI0MDIyODUxNjk1Mg?oc=5
#
# Title: 이탈리아, 외국 완성차업체 유치 위해 테슬라 등과 협의 중 - 글로벌이코노믹
# Link: https://news.google.com/rss/articles/CBMiUWh0dHBzOi8vd3d3LmctZW5ld3MuY29tL2FydGljbGUvR2xvYmFsLUJpei8yMDI0LzAyLzIwMjQwMjI5MDg0MDE0MTgzNjlhMWYzMDk0MzFfMdIBAA?oc=5
#
# Title: 테슬라 모바일 앱 소프트웨어 업데이트 > | BEV - 글로벌오토뉴스
# Link: https://news.google.com/rss/articles/CBMiQ2h0dHA6Ly9nbG9iYWwtYXV0b25ld3MuY29tL2Jicy9ib2FyZC5waHA_Ym9fdGFibGU9YmRfMDEwJndyX2lkPTg3MzDSAQA?oc=5
#
# Title: “테슬라 계약 취소할게”… 폭스바겐 신형 ID.4, 새롭게 바뀐 실내가 '대박' - 오토트리뷴
# Link: https://news.google.com/rss/articles/CBMiP2h0dHBzOi8vd3d3LmF1dG90cmlidW5lLmNvLmtyL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0xNDEzN9IBAA?oc=5
#
# Title: 테슬라와 BYD, 전기차 시대를 뛰어넘는 미래 대결 - 글로벌이코노믹
# Link: https://news.google.com/rss/articles/CBMiUGh0dHBzOi8vd3d3LmctZW5ld3MuY29tL2FydGljbGUvR2xvYmFsLUJpei8yMDI0LzAyLzIwMjQwMjI4MDgyNTQ5NDU5Mzc5MjZhYTE1Ml8x0gEA?oc=5
#
# Title: 애플 '전기차 포기' 선언에…테슬라·리비안 '반등' 시티타임스 CityTimes - Investing.com
# Link: https://news.google.com/rss/articles/CBMiP2h0dHBzOi8va3IuaW52ZXN0aW5nLmNvbS9uZXdzL3N0b2NrLW1hcmtldC1uZXdzL2FydGljbGUtMTAxMzc2OdIBAA?oc=5
#
# Title: 테슬라 스포츠카 로드스터 나온다..과연 출시 일정은? ~데일리카 - 데일리카
# Link: https://news.google.com/rss/articles/CBMiQ2h0dHBzOi8vd3d3LmRhaWx5Y2FyLmNvLmtyL2NvbnRlbnQvbmV3cy5odG1sP3R5cGU9dmlldyZhdXRvSWQ9NTE4MDTSAUdodHRwczovL3d3dy5kYWlseWNhci5jby5rci9jb250ZW50L25ld3MvYW1wLmh0bWw_dHlwZT12aWV3JmF1dG9JZD01MTgwNA?oc=5
#
# Title: 테슬라, '신형 로드스터' 올해 말 발표…1초에 97Km 속도 도달 목표 - 베타뉴스 (BETANEWS)
# Link: https://news.google.com/rss/articles/CBMiJmh0dHBzOi8vbS5iZXRhbmV3cy5uZXQvYXJ0aWNsZS8xNDYwNjgy0gEA?oc=5
#
# Title: 삐걱대던 걸음마 변했다…하루 200만뷰 찍은 '테슬라 로봇' [영상] - 중앙일보
# Link: https://news.google.com/rss/articles/CBMiK2h0dHBzOi8vd3d3Lmpvb25nYW5nLmNvLmtyL2FydGljbGUvMjUyMzEyMjPSAS5odHRwczovL3d3dy5qb29uZ2FuZy5jby5rci9hbXBhcnRpY2xlLzI1MjMxMjIz?oc=5
#
# Title: "땡큐 애플" 테슬라 1.16%-리비안 1.44%, 전기차 일제↑(상보) - 뉴스1
# Link: https://news.google.com/rss/articles/CBMiJmh0dHBzOi8vd3d3Lm5ld3MxLmtyL2FydGljbGVzLz81MzM1NjQw0gEqaHR0cHM6Ly93d3cubmV3czEua3IvYW1wL2FydGljbGVzLz81MzM1NjQw?oc=5
#
# Title: 전기차 시동 끈 애플…최대 수혜자는 테슬라 - 한국경제
# Link: https://news.google.com/rss/articles/CBMiLmh0dHBzOi8vd3d3Lmhhbmt5dW5nLmNvbS9hcnRpY2xlLzIwMjQwMjI4NzE2NTHSASpodHRwczovL3d3dy5oYW5reXVuZy5jb20vYW1wLzIwMjQwMjI4NzE2NTE?oc=5
#
# Title: 테슬라 사이버 트럭 타고 스타벅스에 간 킴 카다시안 - 더블유 코리아
# Link: https://news.google._SAQA?oc=5
#
# Title: [EV 트렌드] 테슬라, 순간 가속력 1.9초 로드스터 출시 2025년 목표 - 오토헤럴드
# Link: https://news.google.com/rss/articles/CBMiPWh0dHA6Ly93d3cuYXV0b2hlcmFsZC5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NTI4MzPSAUBodHRwOi8vd3d3LmF1dG9oZXJhbGQuY28ua3IvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTUyODMz?oc=5
#
# Title: 일론 머스크, 다음 세대 테슬라 로드스터는 2025년 출시 - 토큰포스트
# Link: https://news.google.com/rss/articles/CBMiJ2h0dHBzOi8vd3d3LnRva2VucG9zdC5rci9hcnRpY2xlLTE2NjYxMNIBAA?oc=5
#
# Title: 81조 현금 보유 애플 전기車 포기에 테슬라 등 ‘안도의 한숨’ - 조선비즈 - 조선비즈
# Link: https://news.google.com/rss/articles/CBMiYWh0dHBzOi8vYml6LmNob3N1bi5jb20vaW50ZXJuYXRpb25hbC9pbnRlcm5hdGlvbmFsX2Vjb25vbXkvMjAyNC8wMi8yOC9KV0pRTDVORktGQkRESlM2SEdPTDIzQjNBQS_SAXBodHRwczovL2Jpei5jaG9zdW4uY29tL2ludGVybmF0aW9uYWwvaW50ZXJuYXRpb25hbF9lY29ub215LzIwMjQvMDIvMjgvSldKUUw1TkZLRkJEREpTNkhHT0wyM0IzQUEvP291dHB1dFR5cGU9YW1w?oc=5
#
# Title: 머스크 "테슬라 스포츠카 로드스터, 내년 출시"[송경재의 새벽증시] - MSN
# Link: https://news.google....?oc=5
#
# Title: 미국증시 일제 하락, 테슬라 오르고 엔비디아 내리고.. - 푸드경제신문 organiclife
# Link: https://news.google.com/rss/articles/CBMiPmh0dHA6Ly93d3cuZm9vZG5lY29ub215LmNvbS9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MzU2NjM20gEA?oc=5
#
# Title: “테슬라도 이건 못했다”... 질주하는 엔비디아의 강점은 - 조선비즈 - 조선비즈
# Link: https://news.google.?oc=5
#
# Title: 리오토 뜻밖의 실적에 테슬라 등 전기차 주식 오름세 - 한국경제
# Link: https://news.google.com/rss/articles/CBMiLmh0dHBzOi8vd3d3Lmhhbmt5dW5nLmNvbS9hcnRpY2xlLzIwMjQwMjI2MTQ5MWnSASpodHRwczovL3d3dy5oYW5reXVuZy5jb20vYW1wLzIwMjQwMjI2MTQ5MWk?oc=5
#
# Title: 미국증시 나스닥100 하락...테슬라 '상승' vs 반도체주 '뚝' - 초이스경제
# Link: https://news.google.com/rss/articles/CBMiPmh0dHA6Ly93d3cuY2hvaWNlbmV3cy5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MTI3NDA20gFBaHR0cDovL3d3dy5jaG9pY2VuZXdzLmNvLmtyL25ld3MvYXJ0aWNsZVZpZXdBbXAuaHRtbD9pZHhubz0xMjc0MDY?oc=5
#
# Title: 한 달 만에 옵티머스 또 공개한 테슬라…불붙은 로봇 전쟁 - 서울경제 - 서울경제신문
# Link: https://news.google.com/rss/articles/CBMiK2h0dHBzOi8vd3d3LnNlZGFpbHkuY29tL05ld3NWaWV3LzJENUlFMUVUOFrSASxodHRwczovL20uc2VkYWlseS5jb20vTmV3c1ZpZXdBbXAvMkQ1SUUxRVQ4Wg?oc=5
#
# Title: 서학개미가 가장 많이 거래한 미국주식은 테슬라…ETF·엔비디아도 인기 - 연합인포맥스
# Link: https://news.google.com/rss/articles/CBMiP2h0dHBzOi8vbmV3cy5laW5mb21heC5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NDMwMDAzMNIBQmh0dHBzOi8vbmV3cy5laW5mb21heC5jby5rci9uZXdzL2FydGljbGVWaWV3QW1wLmh0bWw_aWR4bm89NDMwMDAzMA?oc=5
#
# Title: '테슬라 대항마'였는데...리비안·루시드, 수요 둔화에 실적 한파 - SBS Biz
# Link: https://news.google.com/rss/articles/CBMiKWh0dHBzOi8vYml6LnNicy5jby5rci9hcnRpY2xlLzIwMDAwMTU4NTAw0gEtaHR0cHM6Ly9iaXouc2JzLmNvLmtyL2FtcC9hcnRpY2xlLzIwMDAwMTU4NTAw?oc=5
#
# Title: 테슬라 3.87%-리비안 6.26%, 니콜라 제외 전기차 일제↑(종합) - 뉴스1
# Link: https://news.google.com/rss/articles/CBMiJmh0dHBzOi8vd3d3Lm5ld3MxLmtyL2FydGljbGVzLz81MzMyNzk20gEqaHR0cHM6Ly93d3cubmV3czEua3IvYW1wL2FydGljbGVzLz81MzMyNzk2?oc=5
#
# Title: 中 전기차주 급등 효과에 테슬라, 모처럼 4%대 급등 [월가 이종목] - 뉴데일리
# Link: https://news.google.com/rss/articles/CBMiR2h0dHBzOi8vd3d3Lm5ld2RhaWx5LmNvLmtyL3NpdGUvZGF0YS9odG1sLzIwMjQvMDIvMjcvMjAyNDAyMjcwMDAxOC5odG1s0gEA?oc=5
#
# Title: '테슬라 오너들 비상'.. 미국 루시드, 끝판왕 전기 SUV 출시 예고했죠 - MSN
# Link: https://news.google.?oc=5
#
# Title: 테슬라 모델 Y·3 가주 최다 판매 차량 1·2위 - The Korea Daily
# Link: https://news.google.com/rss/articles/CBMiSWh0dHBzOi8vbmV3cy5rb3JlYWRhaWx5LmNvbS8yMDI0LzAyLzI2L2Vjb25vbXkvY2FyLzIwMjQwMjI2MTkyOTQ5NTc1Lmh0bWzSAQA?oc=5
#
# Title: 테슬라 충전소, 다른 전기차도 이용 가능할까? - 테크42
# Link: https://news.google.?oc=5
#
# Title: 물가 지표 발표는? 다우ㆍ나스닥 휘청...테슬라는 상승 에코프로ㆍ포스코홀딩스에 '햇볕' - 핀포인트뉴스
# Link: https://news.google.com/rss/articles/CBMiQWh0dHBzOi8vd3d3LnBpbnBvaW50bmV3cy5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MjQ4ODgy0gFEaHR0cHM6Ly93d3cucGlucG9pbnRuZXdzLmNvLmtyL25ld3MvYXJ0aWNsZVZpZXdBbXAuaHRtbD9pZHhubz0yNDg4ODI?oc=5
#
# Title: "'매그니피센트7'에서 애플·테슬라·구글 빠져야" - 연합인포맥스
# Link: https://news.google.com/rss/articles/CBMiP2h0dHBzOi8vbmV3cy5laW5mb21heC5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NDI5OTcxMdIBQmh0dHBzOi8vbmV3cy5laW5mb21heC5jby5rci9uZXdzL2FydGljbGVWaWV3QW1wLmh0bWw_aWR4bm89NDI5OTcxMQ?oc=5
#
# Title: 테슬라 사이버트럭, 에드먼드 테스트에서 실주행거리 537km 달성 - The Guru (더 구루)
# Link: https://news.google.com/rss/articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NjcyMjDSAQA?oc=5
#
# Title: KB증권 "미국주식 중 '테슬라' 가장 많이 거래해" - 아시아에이
# Link: https://news.google.com/rss/articles/CBMiOmh0dHBzOi8vd3d3LmFzaWFhLmNvLmtyL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0xNjEwNzjSAQA?oc=5
#
# Title: 일론 머스크 "지연된 신형 로드스터 설계 마쳐..내년 출시" - 한국경제
# Link: https://news.google.com/rss/articles/CBMiLmh0dHBzOi8vd3d3Lmhhbmt5dW5nLmNvbS9hcnRpY2xlLzIwMjQwMjI5OTAwMTXSASpodHRwczovL3d3dy5oYW5reXVuZy5jb20vYW1wLzIwMjQwMjI5OTAwMTU?oc=5
#
# Title: KB증권 “개인투자자가 가장 많이 거래한 주식 ‘테슬라’” - 투데이신문
# Link: https://news.google.com/rss/articles/CBMiO2h0dHBzOi8vd3d3Lm50b2RheS5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MTAzNDk30gE-aHR0cHM6Ly93d3cubnRvZGF5LmNvLmtyL25ld3MvYXJ0aWNsZVZpZXdBbXAuaHRtbD9pZHhubz0xMDM0OTc?oc=5
#
# Title: 10년간 공들인 '애플카' 포기…테슬라는 '반색' - TV조선
# Link: https://news.google.com/rss/articles/CBMiSmh0dHBzOi8vbmV3cy50dmNob3N1bi5jb20vc2l0ZS9kYXRhL2h0bWxfZGlyLzIwMjQvMDIvMjgvMjAyNDAyMjg5MDE4MC5odG1s0gFKaHR0cHM6Ly9uZXdzLnR2Y2hvc3VuLmNvbS9tb2JpbGUvc3ZjL2FydGljbGUuYW1wLmh0bWw_Y29udGlkPTIwMjQwMjI4OTAxODA?oc=5
#
# Title: 테슬라 보급형 전기차 출시하면 '잠재수요 10배 증가', 투자사 전망 나와 - 비즈니스포스트
# Link: https://news.google.com/rss/articles/CBMiQWh0dHBzOi8vd3d3LmJ1c2luZXNzcG9zdC5jby5rci9CUD9jb21tYW5kPWFydGljbGVfdmlldyZudW09MzQxOTEx0gEA?oc=5
#
# Title: [성장한계 전기차①] 테슬라 등 수요절벽에 최대위기 맞은 전기차업계 - 뉴스투데이
# Link: https://news.google.com/rss/articles/CBMiMWh0dHBzOi8vd3d3Lm5ld3MyZGF5LmNvLmtyL2FydGljbGUvMjAyNDAyMjc1MDAwMDLSAQA?oc=5
#
# Title: [성장한계 전기차②] 테슬라는 감기, 리비안 루시드는 앓아누울 판 - 뉴스투데이
# Link: https://news.google.com/rss/articles/CBMiMWh0dHBzOi8vd3d3Lm5ld3MyZGF5LmNvLmtyL2FydGljbGUvMjAyNDAyMjg1MDAwMDLSAQA?oc=5
#
# Title: 한국 자동차 소비자 20%...“중국 전기차 BYD(비야디) 구매하겠다!” ~데일리카 - 데일리카
# Link: https://news.google.com/rss/articles/CBMiQ2h0dHBzOi8vd3d3LmRhaWx5Y2FyLmNvLmtyL2NvbnRlbnQvbmV3cy5odG1sP3R5cGU9dmlldyZhdXRvSWQ9NTE4MTTSAUdodHRwczovL3d3dy5kYWlseWNhci5jby5rci9jb250ZW50L25ld3MvYW1wLmh0bWw_dHlwZT12aWV3JmF1dG9JZD01MTgxNA?oc=5
#
# Title: “걷기만 했을 뿐인데…” 머스크가 공개한 '테슬라봇' 영상에 관심 집중 - 전자신문
# Link: https://news.google.com/rss/articles/CBMiJWh0dHBzOi8vd3d3LmV0bmV3cy5jb20vMjAyNDAyMjYwMDAzODnSAQA?oc=5
#
# Title: 체면 구긴 머스크, 로드스터 스포츠카 계획 공개 - 글로벌이코노믹
# Link: https://news.google.com/rss/articles/CBMiUWh0dHBzOi8vd3d3LmctZW5ld3MuY29tL2FydGljbGUvR2xvYmFsLUJpei8yMDI0LzAyLzIwMjQwMjI5MDAzNDUxMzE1MWJlODRkODc2NzRfMdIBAA?oc=5
#
# Title: 테슬라 사이버트럭 한국 왔다..2월말 전시 예상 - 카가이
# Link: https://news.google.com/rss/articles/CBMiN2h0dHBzOi8vd3d3LmNhcmd1eS5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NDg0NTbSAQA?oc=5
#
# Title: '애플카' 개발 포기..테슬라 '환영' 속 암울한 전망 [디지털리포트] - YTN
# Link: https://news.google.com/rss/articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNF8yMDI0MDIyODE2MDQ0MzE2MDPSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDRfMjAyNDAyMjgxNjA0NDMxNjAz?oc=5
#
# Title: 테슬라, 인간같은 로봇 추가영상…빅테크, 휴머노이드 경쟁 - KBS뉴스
# Link: https://news.google.com/rss/articles/CBMiL2h0dHBzOi8vbmV3cy5rYnMuY28ua3IvbmV3cy92aWV3LmRvP25jZD03ODk4Njc50gEA?oc=5
#
# Title: “테슬라·비야디·지리車만 사라”… 中 전기차, 도미노 파산 속 옥석 가리기 본격화 - 조선비즈 - 조선비즈
# Link: https://news.google.com/rss/articles/CBMiYWh0dHBzOi8vYml6LmNob3N1bi5jb20vaW50ZXJuYXRpb25hbC9pbnRlcm5hdGlvbmFsX2Vjb25vbXkvMjAyNC8wMi8yOC9TRVdZMkVMVVZGRlQ3SzJCSDMyNUE0R0VWSS_SAXBodHRwczovL2Jpei5jaG9zdW4uY29tL2ludGVybmF0aW9uYWwvaW50ZXJuYXRpb25hbF9lY29ub215LzIwMjQvMDIvMjgvU0VXWTJFTFVWRkZUN0syQkgzMjVBNEdFVkkvP291dHB1dFR5cGU9YW1w?oc=5
#
# Title: “테슬라가 잔뜩 긴장할 만하네”… 폴스타 3 중국서 생산 개시, 한국 출시는 언제? - 오토트리뷴
# Link: https://news.google.com/rss/articles/CBMiP2h0dHBzOi8vd3d3LmF1dG90cmlidW5lLmNvLmtyL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0xNDExM9IBAA?oc=5
#
# Title: '테슬라 대항마' 리비안·루시드, 주가 하락 심상치 않네 - 헤럴드경제
# Link: https://news.google.com/rss/articles/CBMiNWh0dHBzOi8vYml6LmhlcmFsZGNvcnAuY29tL3ZpZXcucGhwP3VkPTIwMjQwMjI1MDUwMTc00gE6aHR0cHM6Ly9tYml6LmhlcmFsZGNvcnAuY29tL2FtcC92aWV3LnBocD91ZD0yMDI0MDIyNTA1MDE3NA?oc=5
#
# Title: 테슬라 로봇, 인간처럼 걷는다… '옵티머스' 진화 버전 공개 - 문화일보
# Link: https://news.google.com/rss/articles/CBMiP2h0dHBzOi8vd3d3Lm11bmh3YS5jb20vbmV3cy92aWV3Lmh0bWw_bm89MjAyNDAyMjYwMTA3MDgwOTI4NzAwMdIBAA?oc=5
#
# Title: 애플카 포기에 테슬라 주가반등…오펙플러스 감산연장 [뉴욕마감] - 네이트 뉴스
# Link: https://news.google.com/rss/articles/CBMiM2h0dHBzOi8vbmV3cy5uYXRlLmNvbS92aWV3LzIwMjQwMjI5bjAyOTA4P21pZD1uMTEwMdIBAA?oc=5
#
# Title: “신기하게 냄새가 안 나요”… 테슬라 서비스센터 가보니 [백수전의 '테슬람이 간다'] - 한국경제
# Link: https://news.google.com/rss/articles/CBMiLmh0dHBzOi8vd3d3Lmhhbmt5dW5nLmNvbS9hcnRpY2xlLzIwMjQwMjIxODc3OGnSASpodHRwczovL3d3dy5oYW5reXVuZy5jb20vYW1wLzIwMjQwMjIxODc3OGk?oc=5
#
# Title: 테슬라, 인간같은 로봇…걸어다니는 휴머노이드 공개 - 매일신문
# Link: https://news.google.com/rss/articles/CBMiNGh0dHBzOi8vd3d3LmltYWVpbC5jb20vcGFnZS92aWV3LzIwMjQwMjI2MTMzMDI5MTc3MzXSAQA?oc=5
#
# Title: 테슬라 경쟁사 리비안, 올해 성장 제로 전망... 창립자 “인력 10% 감축한 것은 연준 탓” - 포춘코리아
# Link: https://news.google.com/rss/articles/CBMiQGh0dHBzOi8vd3d3LmZvcnR1bmVrb3JlYS5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MzQ4NDLSAUNodHRwczovL3d3dy5mb3J0dW5la29yZWEuY28ua3IvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTM0ODQy?oc=5
#
# Title: “다음 목표는 페라리”… 테슬라 제친 中 비야디, 3억원대 전기차 출시 - 조선비즈 - 조선비즈
# Link: https://news.google.com/rss/articles/CBMiYWh0dHBzOi8vYml6LmNob3N1bi5jb20vaW50ZXJuYXRpb25hbC9pbnRlcm5hdGlvbmFsX2Vjb25vbXkvMjAyNC8wMi8yNi81Vlc2WVlGS0xOQUNUR0hPNTVBQlpKN09OVS_SAXBodHRwczovL2Jpei5jaG9zdW4uY29tL2ludGVybmF0aW9uYWwvaW50ZXJuYXRpb25hbF9lY29ub215LzIwMjQvMDIvMjYvNVZXNllZRktMTkFDVEdITzU1QUJaSjdPTlUvP291dHB1dFR5cGU9YW1w?oc=5
#
# Title: ‘테슬라 대항마’로 급부상하던 리비안·루시드, 전기차 수요 둔화에 일제히 주가 하락! - AVING.net
# Link: https://news.google.com/rss/articles/CBMiOGh0dHBzOi8va3IuYXZpbmcubmV0L25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0xNzg4NDEw0gE7aHR0cHM6Ly9rci5hdmluZy5uZXQvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTE3ODg0MTA?oc=5
#
# Title: 테슬라, “48볼트 시스템으로 차 내 배선량 70%까지 줄일 수 있다” - 글로벌오토뉴스
# Link: https://news.google.com/rss/articles/CBMiQ2h0dHA6Ly9nbG9iYWwtYXV0b25ld3MuY29tL2Jicy9ib2FyZC5waHA_Ym9fdGFibGU9YmRfMDEwJndyX2lkPTg3MjDSAQA?oc=5
#
# Title: 테슬라, 미국 내 브랜드 충성도 상위 9개 중 4 개 차지 - 글로벌오토뉴스
# Link: https://news.google.com/rss/articles/CBMiQ2h0dHA6Ly9nbG9iYWwtYXV0b25ld3MuY29tL2Jicy9ib2FyZC5waHA_Ym9fdGFibGU9YmRfMDEwJndyX2lkPTg3MTLSAQA?oc=5
#
# Title: 밸류업 실망한 개미, 애플·테슬라 대신에 엔비디아... 서학개미 전략 - 머니S
# Link: https://news.google.com/rss/articles/CBMiNGh0dHBzOi8vd3d3Lm1vbmV5cy5jby5rci9hcnRpY2xlLzIwMjQwMjI2MTcwOTU4NDM1MTDSAQA?oc=5
#
# Title: “전기차 사기 게임은 끝났다, 테슬라? 100년 전 포드 보라” - 중앙일보
# Link: https://news.google.com/rss/articles/CBMiK2h0dHBzOi8vd3d3Lmpvb25nYW5nLmNvLmtyL2FydGljbGUvMjUyMzAzNDHSAS5odHRwczovL3d3dy5qb29uZ2FuZy5jby5rci9hbXBhcnRpY2xlLzI1MjMwMzQx?oc=5
#
# Title: '돈나무 언니' 또 담았다…테슬라 4% 급등 시티타임스 CityTimes - Investing.com
# Link: https://news.google.com/rss/articles/CBMiP2h0dHBzOi8va3IuaW52ZXN0aW5nLmNvbS9uZXdzL3N0b2NrLW1hcmtldC1uZXdzL2FydGljbGUtMTAxMTY5OdIBAA?oc=5
#
# Title: 테슬라 0.17%-리비안 4.11%-니콜라 4.57%, 전기차 일제↑(상보) - 뉴스1
# Link: https://news.google.com/rss/articles/CBMiJmh0dHBzOi8vd3d3Lm5ld3MxLmtyL2FydGljbGVzLz81MzM0MTcw0gEqaHR0cHM6Ly93d3cubmV3czEua3IvYW1wL2FydGljbGVzLz81MzM0MTcw?oc=5
#
# Title: '지난해 가장 많이 거래된 미국주식은 테슬라' KB증권, 미국주식 매매 종목 분석 결과 발표 - 한국아이닷컴
# Link: https://news.google.com/rss/articles/CBMiO2h0dHBzOi8vd3d3Lmhhbmtvb2tpLmNvbS9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MTQwMzYy0gE-aHR0cHM6Ly93d3cuaGFua29va2kuY29tL25ld3MvYXJ0aWNsZVZpZXdBbXAuaHRtbD9pZHhubz0xNDAzNjI?oc=5
#
# Title: KB증권 “테슬라, 서학개미 인기 주식 1위” - 파이낸셜투데이
# Link: https://news.google.com/rss/articles/CBMiOmh0dHA6Ly93d3cuZnRvZGF5LmNvLmtyL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0zMTcwMTTSAT1odHRwOi8vd3d3LmZ0b2RheS5jby5rci9uZXdzL2FydGljbGVWaWV3QW1wLmh0bWw_aWR4bm89MzE3MDE0?oc=5
#
# Title: '테슬라 대항마'였는데…리비안, 전기차 한파에 주가 12% '뚝' - 한국경제
# Link: https://news.google.com/rss/articles/CBMiLmh0dHBzOi8vd3d3Lmhhbmt5dW5nLmNvbS9hcnRpY2xlLzIwMjQwMjI1ODYxNWnSASpodHRwczovL3d3dy5oYW5reXVuZy5jb20vYW1wLzIwMjQwMjI1ODYxNWk?oc=5
#
# Title: 테슬라 사이버트럭, 중국 순회…현지 반응 '후끈' - 디지털투데이
# Link: https://news.google.com/rss/articles/CBMiQWh0dHBzOi8vd3d3LmRpZ2l0YWx0b2RheS5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NTA3MjU30gEA?oc=5
#
# Title: 겁 없는 서학개미, 급락 테슬라株에 6900억 쓸어담았다 - 조선일보
# Link: https://news.google.com/rss/articles/CBMiS2h0dHBzOi8vd3d3LmNob3N1bi5jb20vZWNvbm9teS9tb25leS8yMDI0LzAyLzA4LzVLN0JZU1BDS0ZDT0REWDNQVkZUMzdFNEVRL9IBWmh0dHBzOi8vd3d3LmNob3N1bi5jb20vZWNvbm9teS9tb25leS8yMDI0LzAyLzA4LzVLN0JZU1BDS0ZDT0REWDNQVkZUMzdFNEVRLz9vdXRwdXRUeXBlPWFtcA?oc=5
#
# Title: 테슬라, 캐나다에서 곧 사이버트럭 판매 희망…첫 해외 진출 - 베타뉴스 (BETANEWS)
# Link: https://news.google.com/rss/articles/CBMiJmh0dHBzOi8vbS5iZXRhbmV3cy5uZXQvYXJ0aWNsZS8xNDYwMzEx0gEA?oc=5
#
# Title: 삼성운용 테슬라 ETF, 순자산 500억 돌파 - 대한금융신문
# Link: https://news.google.com/rss/articles/CBMiPGh0dHBzOi8vd3d3LmtiYW5rZXIuY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTIxMzIwMtIBP2h0dHBzOi8vd3d3LmtiYW5rZXIuY28ua3IvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTIxMzIwMg?oc=5
#
# Title: "가장 많은 사랑 받은 미국주식은 `테슬라`", KB증권 - 디지털타임스
# Link: https://news.google.com/rss/articles/CBMiQ2h0dHA6Ly93d3cuZHQuY28ua3IvY29udGVudHMuaHRtbD9hcnRpY2xlX25vPTIwMjQwMjI4MDIxMDk5NjMwNDYwMDTSAQA?oc=5
#
# Title: 테슬라 제친 비야디, 페라리와 경쟁 위해 3억 전기차 출시 - 뉴스1
# Link: https://news.google.com/rss/articles/CBMiJmh0dHBzOi8vd3d3Lm5ld3MxLmtyL2FydGljbGVzLz81MzMxNDcx0gEqaHR0cHM6Ly93d3cubmV3czEua3IvYW1wL2FydGljbGVzLz81MzMxNDcx?oc=5
#
# Title: ‘저가 매수’ 테슬라 오늘은 0.17%↑ 이틀 연속 상승 성공 - 뉴스1
# Link: https://news.google.com/rss/articles/CBMiJmh0dHBzOi8vd3d3Lm5ld3MxLmtyL2FydGljbGVzLz81MzM0MTY30gEqaHR0cHM6Ly93d3cubmV3czEua3IvYW1wL2FydGljbGVzLz81MzM0MTY3?oc=5
#
# Title: 탈 많은 테슬라 사이버트럭, 국내판매 준비하나 - 머니S
# Link: https://news.google.com/rss/articles/CBMiNGh0dHBzOi8vd3d3Lm1vbmV5cy5jby5rci9hcnRpY2xlLzIwMjQwMjIzMTY0MDAzMjU4NzTSAQA?oc=5
#
# Title: 서학개미 거래 1순위 종목은 테슬라, ETF는 반도체·AI - 뉴스핌
# Link: https://news.google.com/rss/articles/CBMiMGh0dHBzOi8vd3d3Lm5ld3NwaW0uY29tL25ld3Mvdmlldy8yMDI0MDIyODAwMDk2NdIBMWh0dHBzOi8vbS5uZXdzcGltLmNvbS9uZXdzYW1wL3ZpZXcvMjAyNDAyMjgwMDA5NjU?oc=5
#
# Title: 테슬라 0.17%-리비안 4.11%-니콜라 4.57%, 전기차 일제↑(상보) - 네이트 뉴스
# Link: https://news.google.com/rss/articles/CBMiM2h0dHBzOi8vbmV3cy5uYXRlLmNvbS92aWV3LzIwMjQwMjI4bjAzMTMzP21pZD1uMTEwMdIBAA?oc=5
#
# Title: 테슬라 사이버트럭, 침수 테스트 성공..물웅덩이 통과 입증 - 카가이
# Link: https://news.google.com/rss/articles/CBMiN2h0dHBzOi8vd3d3LmNhcmd1eS5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NDg0NTTSAQA?oc=5
#
# Title: 테슬라, 3만 크레딧 내면 사이버트럭 출고 순번 바꿔준다? - 카가이
# Link: https://news.google.com/rss/articles/CBMiN2h0dHBzOi8vd3d3LmNhcmd1eS5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NDg0NDDSAQA?oc=5
#
# Title: 테슬라는 ‘엔비디아 파티’에 초대받지 못했다 - 뉴스1
# Link: https://news.google.com/rss/articles/CBMiJmh0dHBzOi8vd3d3Lm5ld3MxLmtyL2FydGljbGVzLz81MzMwOTY40gEqaHR0cHM6Ly93d3cubmV3czEua3IvYW1wL2FydGljbGVzLz81MzMwOTY4?oc=5
#
# Title: 테슬라 제친 비야디, 페라리와 경쟁 위해 3억 전기차 출시 시티타임스 CityTimes - Investing.com
# Link: https://news.google.com/rss/articles/CBMiP2h0dHBzOi8va3IuaW52ZXN0aW5nLmNvbS9uZXdzL3N0b2NrLW1hcmtldC1uZXdzL2FydGljbGUtMTAxMDk4MdIBAA?oc=5
#
# Title: 전기차 부진 계속, 테슬라 3% 급락 - 뉴스1
# Link: https://news.google.com/rss/articles/CBMiJmh0dHBzOi8vd3d3Lm5ld3MxLmtyL2FydGljbGVzLz81MzMwNjQz0gEqaHR0cHM6Ly93d3cubmV3czEua3IvYW1wL2FydGljbGVzLz81MzMwNjQz?oc=5
#
# Title: '저가 매수' 테슬라 오늘은 0.17%↑ 이틀 연속 상승 성공 - 네이트 뉴스
# Link: https://news.google.com/rss/articles/CBMiM2h0dHBzOi8vbmV3cy5uYXRlLmNvbS92aWV3LzIwMjQwMjI4bjAyOTY3P21pZD1uMDEwMNIBAA?oc=5
#
# Title: 2023년 전 세계 모델별 베스트 셀링카는 테슬라 모델Y - 네이트뷰
# Link: https://news.google.com/rss/articles/CBMiJ2h0dHBzOi8vdmlldy5uYXRlLmNvbS9hdXRvL3ZpZXcvMTQwNjAzL9IBAA?oc=5
